# %%
numbers=(10,20,30,40)
print(numbers)
print(type(numbers))

# %%
numbers=10,20,30,40
print(numbers)
print(type(numbers))

# %%
numbers=tuple(["Ab","cd"])
print(type(numbers))

# %%
numbers=list(("Ab","cd"))
print(type(numbers))

# %%
fruits=("apple","Mango","Banana")
print(fruits[-1])
print(fruits[2])
print(fruits[1])

# %%
fruits=("apple","Banana","Orange","Mango","Guava","Pineapple")
print(fruits[1:4])
print(fruits[::-1])
print(fruits[::2])

# %%
fruits=("apple","Banana","Orange","Mango","Guava","PineApple")
for fruit in fruits:
    print(fruit)

# %%
fruits=("apple","Banana","Orange","Mango","Guava","PineApple")
print("=======fruits========")
for in_num in range(len(fruits)):
    
    print(in_num+1,fruits[in_num])
print("=====================")

# %%
fruits=("apple","Banana","Orange","Mango","Guava","PineApple")
print("apple" in fruits)

# %%
fruits=("apple","Banana","Orange","Mango","Guava","PineApple")
print("kiwi" in fruits)

# %%
total_products=int(input("Enter the Number of products"))
grand_total=0
products_list=[]
print("Enter Number of Products:",total_products)
print("="*40)
for pro_num in range(1,total_products+1):
    print("enter details of product:",pro_num)
    pro_id=int(input("product id"))
    pro_name=(input("Pro name"))
    price=int(input("Price:"))
    quantity=int(input("Quantity"))
    products_list.append((pro_id,pro_name,price,quantity))
    print(" product ID :",pro_id)
    print("Product Name:",pro_name)
    print("Price       :",price)
    print("Quantity    :",quantity)
    grand_total+=price*quantity

    
print("{:<5}{:<10}{:<15}{:<5}{:<10}".format("Id","NAME","PRICE","QTY","TOTAL"))
print("="*40)
for product in products_list:
    total_price=product[2]*product[3]
    print("{:<5}{:<10}{:<15}{:<5}{:<10}".format(
    product[0],
    product[1],
    product[2],
    product[3],
    total_price
    ))
print("="*40)
print("Grand Total:",grand_total)

# %%
student={
    "name":"Isfania",
    "Age":21,
    "course":"Data science"
}
student["dept"]="CSE"
print(student)
print(student.get("dept"))

# %%
student={
    "name":"Isfania",
    "Age":21,
}
student.update(
    {"course":"Datascience",
    "dept":"CSE"}
)
print(student)

# %%
student={
    "name":"Isfania",
    "Age":21,
}
student.update(
    {"course":"Datascience",
    "dept":"CSE"}
)
student.pop("course")
student.popitem()
del student["name"]
print(student) #key value key_index

# %%
car={"brand":"Ford",
      "Model":"mustang",
      "Year":1964,
      "Color":"Blue"
      }
print(car["Model"])
print(car["Year"])
print(car.get("Year"))#if no year present None will be the Ans
print(car.get("color","Not Available"))
print(car.keys())
print(car.values())
print(car.items())
del car["Year"]
print ("After deleting:",car)
print("Deleted value usin POP:",car.pop("Model"))
print("Deleted value USING POPITEM:",car.popitem())
print("Cleared Dict:",car.clear())

# %%
student={"name":"Isfania",
        "skills":["Python","SQL","Java"],
        "student1":{
        "name":"Jerha",
        "age":23
        },
        "student2":{
            "name":"Supriya",
            "age":18
        }
}
        
print(student["skills"])
print(student["skills"][0])
print(student["student1"]["name"])
print(student["student1"]["age"])

# %%
student=[
        {
        "name":"Jerha",
        "age":23
        },
        {
            "name":"Supriya",
            "age":18
        },
        {
            "name":"Supriya123",
            "age":18
        }
]
for students in student:
    print(students["name"])

# %%
students_details={}
while True:
    print("1.Add Student")
    print("2.View all students")
    print("3.Search student by ID")
    print("4.Update student Fee")
    print("5.Delete Student")
    print("6.Exit")
    choice=int(input("Enter Your Choice:"))
    print("Enter your Choice :",choice)
    if choice == 1:
        student_id=int(input("Enter Student_ID:"))
        stu_name=input("Enter Student Name:")
        stu_course=input("Enter The Course:")
        course_fees=int(input("Enter The Fees:"))
        payment_status=input("Payment Status:")
        print("Enter Student_ID:",student_id)
        print("Enter Student Name:",stu_name)
        print("Enter The Course:",stu_course)
        print("Enter The Fees:",course_fees)
        print("Payment Status:",payment_status)
        students_details[student_id]={
                "Name":stu_name,
                "Course":stu_course,
                "Fees":course_fees,
                "Payment status":payment_status
        }
    elif choice == 2:
        for s_id,student in students_details.items():
            print("="*40)
            print("Student Details")
            print("-"*40)
            print("Roll Number    : ",s_id)
            print(" Name          : ",stu_name)
            print("Course         : ",stu_course)
            print("Fees           : ",course_fees)
            print("Payment Status : ",payment_status)
            print("="*40)
    elif choice == 3:
        search_id = int(input("Enter the Student_ID : "))
        if search_id in students_details:
            student = students_details[search_id]
            print("="*40)
            print("Student Found")
            print("-"*40)
            print("Roll Number    : ", search_id)
            print("Name           : ", student["Name"])
            print("Course         : ", student["Course"])
            print("Fees           : ", student["Fees"])
            print("Payment Status : ", student["Payment status"])
            print("="*40)
        else:
            print("No student ID:", search_id)
    elif choice == 3:
        search_id = int(input("Enter Student_ID to search: "))
        print("Enter Search Id:",search_id)
        if search_id in students_details:
            student = students_details[search_id]
            print("="*40)
            print("Student ID Found")
            print("-"*40)
            print("Roll Number    : ", search_id)
            print("Name           : ", student["Name"])
            print("Course         : ", student["Course"])
            print("Fees           : ", student["Fees"])
            print("Payment Status : ", student["Payment status"])
            print("="*40)
        else:
            print("No student ID Found:", search_id)
    elif choice == 4:
        student_id=int(input("Enter Student ID:"))
        print("Enter student ID:",student_id)
        if student_id in students_details:
            new_fees=int(input("Enter THE UPdated fees"))
            print(" Enter Updated fees:",new_fees)
            students_details[student_id]["Fees"]=new_fees
            student=students_details[student_id]
            print("Fees Updated Successfully")
            print("-"*40)
            print("Roll Number    : ", student_id)
            print("Name           : ", student["Name"])
            print("Course         : ", student["Course"])
            print("Fees           : ", student["Fees"])
            print("Payment Status : ", student["Payment status"])
            print("="*40)
        else:
            print("Student Id Not Found")
    elif choice == 5:
        student_id_id = int(input("Enter Student_ID to delete: "))
        if student_id in students_details:
            del students_details[student_id]
            print("Student with ID", student_id, "deleted successfully!")
        else:
            print("No student_ID:", student_id)
    elif choice==6:
        print("EXIT")
        break
