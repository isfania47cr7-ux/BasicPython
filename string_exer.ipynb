# %%
s=10
print(s)

# %%
print("hello world")

# %%
str="school"
print(str)

# %%
name12="h"
print(name12)

# %%
_age=12
print(_age)

# %%
name="akhil mano"
print(name[2])
print(name[-1])
print(name[6:9])
print(name[2:5])
print(name[0:10:2])
print(name[::-1])

# %%
fir_name="akhil"
sec_name="mano"
print(fir_name + sec_name)

# %%
stu_name="Vijin"
stu_name2=stu_name+" is the best student"
print(stu_name)
print(stu_name2)

# %%
print("vijin \n is the best student")

# %%
print("the \\ student")
print(r"the student \\")

# %%
name="mano"
print(f"{name} is the best number")
