# %%
s=10
print(s)

# %%
print("hello world")

# %%
str="school"
print(str)

# %%
name12="h"
print(name12)

# %%
_age=12
print(_age)

# %%
name="akhil mano"
print(name[2])
print(name[-1])
print(name[6:9])
print(name[2:5])
print(name[0:10:2])
print(name[::-1])

# %%
fir_name="akhil"
sec_name="mano"
print(fir_name + sec_name)

# %%
stu_name="Vijin"
stu_name2=stu_name+" is the best student"
print(stu_name)
print(stu_name2)

# %%
print("vijin \n is the best student")

# %%
print("the \\ student")
print(r"the student \\")

# %%
name="abc"
print(name)

# %%
l=input()
print(type(l))
print(len(name))

# %%
age=18
age_1="18"
age_2=18.9
print(type(age))
print(type(age_1))
print(type(age_2))

# %%
student=input()

print(student.upper())
print(student.lower())
print(student.title())
print("name:",student.capitalize())

# %%
student_1=" isfania"
print(student_1.strip())

# %%
print("= "*10 + "STUDENT PROFILE" + "= "*10)
print()
name=input("Name")
email=input("Email")
phone=input("Phone")
Course=input("Course")
print("Name            :   ",name)
print("Email           :   ",email)
print("Phone           :   ",phone)
print("Course          :   ",Course)
print()

print("- "*10 + "STRING ANALYSIS"  + "- "*10)
print()
print("Name Length     :   ",len(name))
print("Name Upper      :   ",name.upper())
print("Name Lower      :   ",name.lower())
print("First Name      :   ",name[0])
print("Last Character  :   ",name[-1])
print("Email Domain    :   ",email[8::])
print("Course Length   :   ",len(Course))
print()
print("= "*25)

# %%
sen="I am the Best"
print(sen.split())
print(sen.split("e"))
print(sen.split("e",1))
print(sen.replace("am","will be"))
