# %%
fruits=["apple","banana","orange"]
print(fruits[0])

# %%
fruits=["apple","banana",["hello",21,["hi","hello world"]],"orange"]

print(fruits[2][2][1])

# %%
number=[10,20,30,40,50,60]
print(number[1:5])

# %%
number=[10,20,30,40,50,60]
print(number[::-1])
print(number)
# Out:
# [60, 50, 40, 30, 20, 10]
# [10, 20, 30, 40, 50, 60]

# %%
names=["isfania"]
names.insert(0,"Tharsis")
names.insert(1,"cleoda")

print(names)

# %%
names.append(["sweet","sugar"])
print(names)

# %%
names.extend(["jerha","suppri"])
print(names)

# %%
products=["Soap","Shampoo"]
products.insert(0,"Face wash")
print(products)
products.append(("hello",))#tuple
print(products)
products.extend("gfhgfhgh")
print(products)

# %%
products=["Soap","Shampoo"]
products.remove("Soap")
print(products)

# %%
products=["Soap","Shampoo"]
products.pop()
print(products)

# %%
products=["Soap","Shampoo"]
products.extend(["pow","serum","gel"])
products

# %%
value=products.remove("Soap")
print(value)
print(products)

# %%
value=products.pop(2)#gives deleted value in returm
print(value)
print(products)

# %%
value=products.clear()
print(value)
print(products)

# %%
num=[10,20,30,40,50]
num.sort(reverse=True)
print(num)
num.remove(30)
num.append(70)

# %%
numbers=[10,20,30,40,50]
squares=[]
for number in numbers:
    if x==20:
        squares.append(number ** 2)
print(squares)             #list comprehension

# %%
numbers=[10,20,30,40,50]
squares=[number ** 2 for number in numbers ]
print(squares)

# %%
digits=[1,2,3,4,5]
even=[]
for digit in digits:
    if digit % 2==0:
        even.append(digit)
print(even)

# %%
digits=[1,2,3,4,5]
even=[digit for digit in digits if digit % 2==0]
print(even)

# %%
for digit in digits:
    if digit % 2==0:
        return digit
