# %%
print("Hi")
sen="I am the Best"
print(sen.split())
print(sen.split("e"))
print(sen.split("e",1))
print(sen.replace("am","will be"))

# %%
age=int(input("age"))
print(age)
if age > 18 and age<25:
    print("U are Selected")
else
    print(" Eligible")

# %%
age=int(input("age"))
print(age)
if age > 18 and age<25:
    print("U are Selected")
elif(age==18):
    print("U are eligible")
else:
    print("Not Eligible")

# %%
age=int(input("age"))
percentage=int(input("Percentage"))
print(age)
print(percentage)
if age > 18 and age<25:
    if percentage > 70:
        print("Team involvement")
    else:
        print("Not Involved")
elif(age==18):
    print("U are eligible")
else:
    print("Not Eligible")

# %%
age=int(input("age"))
percentage=int(input("Percentage"))
print(age)
print(percentage)
if age > 18 or age<25:
    if percentage > 70 or percentage == 50:
        print("Team involvement")
    else:
        print("Not Involved")
elif(age==18):
    print("U are eligible")
else:
    print("Not Eligible")

# %%
stu_name=input("Enter Student Name:") 
stu_id=input("Student Id")
Test_score=int(input("Enter Test Score:"))

print("Enter Student Name  : ",stu_name)

print("Enter Student Id    : ",stu_id)

print("Enter Student Score : ",Test_score)
print()
print("= "*5 +"REPORT" + "= "*5)
print("Name  : ",stu_name)
print("ID    : ",stu_id)
print("Score : ",Test_score)

if (Test_score >= 95 and Test_score <= 100):
    print("GRADE :  A")
elif(Test_score <= 94 and Test_score >= 90):
    print("GRADE :  B")
elif(Test_score <= 89 and Test_score >= 85):
    print("GRADE :  C")
elif(Test_score <= 84 and Test_score >= 80):
    print("GRADE :  D")
elif(Test_score <= 79 and Test_score >= 70):
    print("GRADE :  E")
else:
    print("GRADE :  F")

# %%
emp_name=input("Employee Name:")
score=int(input("Performance Score:"))
print("Employee Name     :",emp_name)
print("Performance score :",score)
      
if (score >=95):
    print("Result        : Captain Candidate")
elif(score <= 94 and score >= 90):
    print("Result      : Selected")
elif(score <= 89 and score >= 85):
    print("Result      : Very Good")
elif(score <=84 and score >=80):
    print("Result      : Good")
else:
    print("Result    :   Needs Improvement")

# %%
name =input("Name:").upper().lower()
print("Name:",name)
age=int(input("age"))
print("Age:",age)
degree=input("degree").upper()
print("Degree:",degree)
percentage=int(input("Percentage"))
print("Perecentage:",percentage)
passport=input("passport" ).upper().lower()
print("Passport:",passport)
python=input("Python").upper().lower()
print("Knows Python :",python)
java=input("Java").upper().lower()
print("Knows Java:",java)
backlog=int(input("Backlog"))
print("Has any Backlog:",backlog)
if (age >= 21 and age <= 30):
    if degree in ("BE", "BTECH" ,"BCA", "MCA"):
        if percentage >= 70:
            if python ==  "YES" or java == "YES" :
                if backlog == 0:
                    if passport == "YES" :
                        print("Eligible")
                        pass
                    else:
                        print("No Passport")
                else:
                    print("has arrears")
            else:
                print("Doesnt know Python Or java")
        else:
            print("Percentage doent match")
    else:
        print("Degree Doesnt match")
else:
    print(" Not Eligible as per age")
