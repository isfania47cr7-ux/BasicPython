# %%
print("Super")

# %%
name =input("Name:").lower()
print("Name:",name)
age=int(input("age"))
print("Age:",age)
degree=input("degree").upper()
print("Degree:",degree)
percentage=int(input("Percentage"))
print("Perecentage:",percentage)
python=input("Python").lower()
print("Knows Python :",python)
java=input("Java").lower()
print("Knows Java:",java)
passport=input("passport" ).lower()
print("Passport:",passport)
backlog=input("Backlog")
print("Has any Backlog:",backlog)
if (age >= 21 and age <= 30):
    if degree in ("BE", "BTECH" ,"BCA", "MCA"):
        if percentage >= 70:
            if python ==  "yes" or java == "yes" :
                if(passport == "yes"):
                    if(backlog == "no"):
                        print("Eligible")
                    else:
                        print("Not Eligible due to Backlog")
                else:
                    print("No passport")
            else:
                print("doesnt know python or java")
        else:
            print("Percentage not eligible")
    else:
        print("Degree doesnt match")
else:
    print("Age Not Eligible")

# %%
acc_name="John"
pin=1234
acc_balance=5000
atm_pin=int(input("Enter PIN : "))
withdrawn_amount=int(input("Enter Withdrawal Amount : "))
if atm_pin == pin:
    if withdrawn_amount <= acc_balance:
        print(f"Welcome, {acc_name} !")
        print("Transaction succesfull")
        print("Withdrawn Amount:",withdrawn_amount)
        print("Remaining Balance:",acc_balance-withdrawn_amount)
    else:
        print("Insufficient Balance")
else:
    print("Invalid Pin")

# %%
for i in range(5):
    print(i)

# %%
for i in range(1,5):
    print(i)

# %%
fruits=["apple","banana","Orange","Mango","Grapes"]
for item in fruits:
    print(item)

# %%
name="isfania"
for ch in name:
    print(ch)

# %%
products=["soap","shampoo","conditioner"]
for things in products:
    print(things)

# %%
for num in range(1,11):
    if num%2==0:
        print(num)

# %%
for num in range(2,11,2):
    
        print(num)

# %%
number=int(input())
for i in range(1,11):
    
        print(f"{number} * {i} =", i*number)

# %%
for num in range(1,10):
    pass

# %%
fruits=["apple","banana","Orange","Mango","Grapes"]
if "Orange" in fruits:
    print("Available")
else:
    print("Not available")

# %%
for num in range(1,10):
    if num == 5 :
        continue
else:
    print("Hello")

# %%
for i in range(5):
    print(f"Iteration{i}")

# %%
for count in range(1,10,2):
    print(count)

# %%
for  i in range(1,10):
    
        
    print(F" 5 * {i} = {i*5}")

# %%
#odd numbers printing using for loop
for num in range(1,11):
    if num % 2==0:
        continue
    print(f"odd numbers:{num}")

# %%
# searching for the target number to be found
i=int(input())
for num in range(1,10):
    if num == i:
        
        print(f"Num Found : {num}")

# %%
#stop searching once the target number is found
i=int(input())
for num in range(10):
    if num == i:
        break
    print(f"Num Found : {i}")

# %%
#stop searching once the target number is found

for num in range(1,10):
    if num == 5:
        print("found 5 stopping the loop")
        break
    print(f"checking loop : {num}")

# %%
for num in range(1,4):
    if num == 2:
        pass
    print(f"processing:{num}")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        continue
    else:
        print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        continue
    else:
        print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        continue
else:
    print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        break
    else:
        print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        break
else:
        print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        pass
    else:
        print("Not Found")

# %%
fruits=["apple","banana","grapes","mango","papaya"]
for fruit in fruits:
    if fruit == "grapes":
        print("Found IT")
        pass
else:
        print("Not Found")
